# %% [markdown]
# # Hangman RL Agent (with HMM Oracle) and Evaluation
#
# This notebook builds a Hangman environment and a simple reinforcement learning agent that uses an HMM-based letter oracle trained on the provided corpus.
#
# What you'll see:
#
# - A lightweight Hangman environment with 6 lives
# - Linear Q-learning agent over hand-crafted features that include the HMM letter probabilities
# - Training on words from the training corpus
# - Visualizations: rewards, success rate, and mistake metrics over time
# - Evaluation on the provided `test.txt` with required metrics and the final score

# %%
# Imports and setup
import os, re, math, json
from collections import Counter
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import trange

sns.set(style="whitegrid")

LETTERS = [chr(ord('a')+i) for i in range(26)]
LETTER_TO_IDX = {c:i for i,c in enumerate(LETTERS)}
IDX_TO_LETTER = {i:c for c,i in LETTER_TO_IDX.items()}
EOS = '<EOS>'
EOS_IDX = 26
VOCAB = LETTERS + [EOS]
VOCAB_SIZE = len(VOCAB)
RNG = np.random.default_rng(123)

# utils

def clean_word(w: str):
    return re.sub(r"[^a-z]", "", w.strip().lower())

def load_words(path):
    with open(path, 'r', encoding='utf-8', errors='ignore') as f:
        words = [clean_word(x) for x in f if x.strip()]
    return [w for w in words if w]

# Training corpus with fallback
TRAIN_PATH = 'data/corpus.txt' if os.path.exists('data/corpus.txt') else 'small_corpus.txt'
train_words = load_words(TRAIN_PATH)
print(f"Train words: {len(train_words)} from {TRAIN_PATH}")

# Test set (required)
TEST_PATH = 'data/test.txt'
assert os.path.exists(TEST_PATH), "test.txt not found in data/"

test_words = load_words(TEST_PATH)
print(f"Test words: {len(test_words)} from {TEST_PATH}")
# Out:
# C:\Users\akash\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_statistics.py:32: UserWarning: A NumPy version >=1.23.5 and <2.3.0 is required for this version of SciPy (detected version 2.3.4)
#   from scipy.stats import gaussian_kde
# Train words: 50000 from data/corpus.txt
# Test words: 2000 from data/test.txt

# %%
# Load HMM artifacts if available, validate shapes
import numpy as np
HMM_AVAILABLE = False
startprob = transmat = emissionprob = None

if os.path.exists('hmm_artifacts.npz'):
    try:
        data = np.load('hmm_artifacts.npz', allow_pickle=True)
        sp = data.get('startprob', None)
        tm = data.get('transmat', None)
        ep = data.get('emissionprob', None)
        ok = True
        if sp is None or tm is None or ep is None:
            ok = False
        else:
            # basic shape checks
            if sp.ndim != 1:
                ok = False
            else:
                n_states = sp.shape[0]
                if tm.shape != (n_states, n_states):
                    ok = False
                if ep.shape[0] != n_states:
                    ok = False
                # must have at least 27 symbols (26 letters + EOS)
                if ep.shape[1] < 27:
                    ok = False
        if ok:
            startprob, transmat, emissionprob = sp, tm, ep
            HMM_AVAILABLE = True
            print('Loaded HMM artifacts (validated)')
        else:
            print('HMM artifacts present but invalid shape; falling back to frequency oracle')
    except Exception as e:
        print('Failed to load HMM artifacts; falling back to frequency oracle:', e)
else:
    print('HMM artifacts not found, falling back to frequency-based oracle')
# Out:
# Loaded HMM artifacts (validated)

# %%
# HMM-based letter oracle (with frequency fallback)

def forward_state_probs(mask: str, startprob, transmat, emissionprob):
    if startprob is None:
        return []
    L = len(mask)
    if L == 0:
        return []
    alphas = []
    alpha = startprob.copy()
    ch0 = mask[0]
    if ch0 != '_' and ch0 in LETTER_TO_IDX:
        alpha = alpha * emissionprob[:, LETTER_TO_IDX[ch0]]
    alpha = alpha / (alpha.sum() + 1e-12)
    alphas.append(alpha)
    for i in range(1, L):
        alpha = alpha @ transmat
        chi = mask[i]
        if chi != '_' and chi in LETTER_TO_IDX:
            alpha = alpha * emissionprob[:, LETTER_TO_IDX[chi]]
        alpha = alpha / (alpha.sum() + 1e-12)
        alphas.append(alpha)
    return alphas

# Precompute global letter frequency on train_words for fallback
fallback_counts = Counter()
for w in train_words:
    fallback_counts.update(list(w))
fb_total = sum(fallback_counts[c] for c in LETTERS) + 1e-12
fallback_probs_global = np.array([fallback_counts.get(c, 0)/fb_total for c in LETTERS])


def hmm_letter_oracle(mask: str, guessed: set[str]):
    if HMM_AVAILABLE and startprob is not None:
        alphas = forward_state_probs(mask, startprob, transmat, emissionprob)
        if not alphas:
            probs = fallback_probs_global.copy()
        else:
            agg = np.zeros(26)
            unknown_positions = 0
            for i, ch in enumerate(mask):
                if ch == '_':
                    unknown_positions += 1
                    state_mix = alphas[i]
                    letter_mix = state_mix @ emissionprob[:, :26]
                    agg += letter_mix
            if unknown_positions > 0:
                probs = agg / (unknown_positions + 1e-12)
            else:
                probs = fallback_probs_global.copy()
    else:
        probs = fallback_probs_global.copy()

    # zero out guessed letters
    for g in guessed:
        if g in LETTER_TO_IDX:
            probs[LETTER_TO_IDX[g]] = 0.0
    s = probs.sum()
    if s <= 1e-12:
        # fallback uniform over unguessed
        available = [c for c in LETTERS if c not in guessed]
        if not available:
            return {c: 1.0/26 for c in LETTERS}
        p = 1.0/len(available)
        return {c: (p if c in available else 0.0) for c in LETTERS}
    probs = probs / s
    return {IDX_TO_LETTER[i]: probs[i] for i in range(26)}

# %%
# Hangman environment and helpers
MAX_LIVES = 6

def mask_word(word: str, guessed: set[str]):
    return ''.join(ch if ch in guessed else '_' for ch in word)


def step_env(word: str, mask: str, guessed: set[str], action: str, lives: int):
    repeated = action in guessed
    wrong = False
    reward = 0.0
    guessed = set(guessed)

    if repeated:
        reward -= 2.0
        return mask, guessed, lives, reward, False, True, False

    guessed.add(action)
    if action in word:
        new_mask = mask_word(word, guessed)
        reward += 2.0
        done = new_mask == word
        if done:
            reward += 10.0
        return new_mask, guessed, lives, reward, done, False, False
    else:
        lives -= 1
        reward -= 1.0
        done = lives <= 0
        if done:
            reward -= 10.0
        return mask, guessed, lives, reward, done, False, True

# %%
# Feature construction for Linear Q-Learning
MAX_WORD_LEN = max(max((len(w) for w in train_words), default=1), max((len(w) for w in test_words), default=1))
VOWELS = set('aeiou')


def available_actions(guessed: set[str]):
    return [c for c in LETTERS if c not in guessed]


def hmm_probs_vector(mask: str, guessed: set[str]):
    d = hmm_letter_oracle(mask, guessed)
    return np.array([d[c] for c in LETTERS], dtype=float)


def featurize(mask: str, guessed: set[str], lives: int, probs_vec: np.ndarray, action: str):
    # Stats
    length_norm = len(mask) / MAX_WORD_LEN
    blanks_norm = mask.count('_') / max(1, len(mask))
    lives_norm = lives / MAX_LIVES
    guessed_norm = len(guessed) / 26.0
    action_idx = LETTER_TO_IDX[action]

    # Feature vector: [bias, action_one_hot(26), hmm_prob[action], vowel, length_norm, blanks_norm, lives_norm, guessed_norm]
    feat = np.zeros(1 + 26 + 1 + 1 + 4, dtype=float)
    pos = 0
    feat[pos] = 1.0; pos += 1  # bias
    feat[pos + action_idx] = 1.0; pos += 26  # action one-hot
    feat[pos] = probs_vec[action_idx]; pos += 1
    feat[pos] = 1.0 if action in VOWELS else 0.0; pos += 1
    feat[pos] = length_norm; pos += 1
    feat[pos] = blanks_norm; pos += 1
    feat[pos] = lives_norm; pos += 1
    feat[pos] = guessed_norm; pos += 1
    return feat

FEATURE_DIM = featurize('_', set(), MAX_LIVES, np.ones(26)/26, 'a').shape[0]
print('Feature dim =', FEATURE_DIM)
# Out:
# Feature dim = 33

# %%
# Linear Q-learning agent
ALPHA = 0.1
GAMMA = 0.95
EPSILON = 0.2
EPS_MIN = 0.05
EPS_DECAY = 0.995
EPISODES = 15000

w = np.zeros(FEATURE_DIM, dtype=float)


def q_value(mask, guessed, lives, probs_vec, action):
    f = featurize(mask, guessed, lives, probs_vec, action)
    return float(np.dot(w, f))


def best_action(mask, guessed, lives, probs_vec):
    acts = available_actions(guessed)
    if not acts:
        return None, 0.0
    qvals = [q_value(mask, guessed, lives, probs_vec, a) for a in acts]
    idx = int(np.argmax(qvals))
    return acts[idx], qvals[idx]


train_rewards = []
train_wins = []
train_wrong = []
train_repeated = []

for ep in trange(EPISODES, desc='Training'):
    word = train_words[RNG.integers(0, len(train_words))]
    guessed = set()
    mask = '_' * len(word)
    lives = MAX_LIVES
    total_reward = 0.0
    wrongs = 0
    repeats = 0

    done = False
    while not done:
        probs_vec = hmm_probs_vector(mask, guessed)
        if RNG.random() < EPSILON:
            # epsilon exploration: sample by HMM probs but only among unguessed
            acts = available_actions(guessed)
            if not acts:
                break
            weights = np.array([probs_vec[LETTER_TO_IDX[a]] for a in acts], dtype=float)
            s = weights.sum()
            if s <= 1e-12:
                a = acts[RNG.integers(0, len(acts))]
            else:
                weights = weights / s
                a = RNG.choice(acts, p=weights)
        else:
            a, _ = best_action(mask, guessed, lives, probs_vec)
            if a is None:
                break

        # env step
        new_mask, new_guessed, new_lives, r, done, repeated, wrong = step_env(word, mask, guessed, a, lives)
        total_reward += r
        wrongs += int(wrong)
        repeats += int(repeated)

        # target
        if not done:
            next_probs = hmm_probs_vector(new_mask, new_guessed)
            a2, qmax = best_action(new_mask, new_guessed, new_lives, next_probs)
            target = r + GAMMA * qmax
        else:
            target = r

        # update
        f = featurize(mask, guessed, lives, probs_vec, a)
        qsa = float(np.dot(w, f))
        w += ALPHA * (target - qsa) * f

        mask, guessed, lives = new_mask, new_guessed, new_lives

    train_rewards.append(total_reward)
    train_wins.append(int(mask == word))
    train_wrong.append(wrongs)
    train_repeated.append(repeats)

    # decay epsilon
    EPSILON = max(EPS_MIN, EPSILON * EPS_DECAY)

print('Training complete.')
# Out:
# Training: 100%|██████████| 15000/15000 [00:14<00:00, 1028.08it/s]
# Training complete.

# %%
# --- Grid search utilities: train_agent, evaluate_agent, and grid search runner
from itertools import product
import time
def train_agent(params, verbose=False):
    """Train linear Q agent with params dict. Returns trained weight vector and histories."""
    EPISODES = int(params.get('EPISODES', 5000))
    ALPHA = float(params.get('ALPHA', 0.1))
    GAMMA = float(params.get('GAMMA', 0.95))
    EPSILON = float(params.get('EPSILON', 0.2))
    EPS_MIN = float(params.get('EPS_MIN', 0.05))
    EPS_DECAY = float(params.get('EPS_DECAY', 0.995))
    seed = int(params.get('seed', 123))
    rng = np.random.default_rng(seed)
    # local weight vector (do not touch global w)
    local_w = np.zeros(FEATURE_DIM, dtype=float)
    train_rewards_local = []
    train_wins_local = []
    train_wrong_local = []
    train_repeated_local = []
    EPS = EPSILON
    for ep in range(EPISODES):
        word = train_words[rng.integers(0, len(train_words))]
        guessed = set()
        mask = '_' * len(word)
        lives = MAX_LIVES
        total_reward = 0.0
        wrongs = 0
        repeats = 0
        done = False
        while not done:
            probs_vec = hmm_probs_vector(mask, guessed)
            if rng.random() < EPS:
                acts = available_actions(guessed)
                if not acts:
                    break
                weights = np.array([probs_vec[LETTER_TO_IDX[a]] for a in acts], dtype=float)
                s = weights.sum()
                if s <= 1e-12:
                    a = acts[rng.integers(0, len(acts))]
                else:
                    weights = weights / s
                    a = rng.choice(acts, p=weights)
            else:
                # greedy by local_w
                acts = available_actions(guessed)
                if not acts:
                    break
                qvals = []
                for a in acts:
                    f = featurize(mask, guessed, lives, probs_vec, a)
                    qvals.append(float(np.dot(local_w, f)))
                a = acts[int(np.argmax(qvals))]
            new_mask, new_guessed, new_lives, r, done, repeated, wrong = step_env(word, mask, guessed, a, lives)
            total_reward += r
            wrongs += int(wrong)
            repeats += int(repeated)
            # compute target
            if not done:
                next_probs = hmm_probs_vector(new_mask, new_guessed)
                acts2 = available_actions(new_guessed)
                if not acts2:
                    qmax = 0.0
                else:
                    qvals2 = []
                    for a2 in acts2:
                        f2 = featurize(new_mask, new_guessed, new_lives, next_probs, a2)
                        qvals2.append(float(np.dot(local_w, f2)))
                    qmax = float(np.max(qvals2))
                target = r + GAMMA * qmax
            else:
                target = r
            # update local_w
            f = featurize(mask, guessed, lives, probs_vec, a)
            qsa = float(np.dot(local_w, f))
            local_w += ALPHA * (target - qsa) * f
            mask, guessed, lives = new_mask, new_guessed, new_lives
        train_rewards_local.append(total_reward)
        train_wins_local.append(int(mask == word))
        train_wrong_local.append(wrongs)
        train_repeated_local.append(repeats)
        EPS = max(EPS_MIN, EPS * EPS_DECAY)
        if verbose and (ep+1) % max(1, EPISODES//5) == 0:
            print(f"ep {ep+1}/{EPISODES}: wins={np.mean(train_wins_local[-100:]):.3f}")
    return {
        'w': local_w,
        'train_rewards': train_rewards_local,
        'train_wins': train_wins_local,
        'train_wrong': train_wrong_local,
        'train_repeated': train_repeated_local,
        'params': params,
    }
"""Evaluation runner that uses a provided weight vector to play test set and return metrics"""
def evaluate_agent(w, words=None):
    if words is None:
        words = test_words
    def q_value_local(mask, guessed, lives, probs_vec, action):
        f = featurize(mask, guessed, lives, probs_vec, action)
        return float(np.dot(w, f))
    def play_game_local(word):
        guessed = set()
        mask = '_' * len(word)
        lives = MAX_LIVES
        wrongs = 0
        repeats = 0
        total_guesses = 0
        done = False
        while not done:
            probs_vec = hmm_probs_vector(mask, guessed)
            acts = available_actions(guessed)
            if not acts:
                break
            qvals = [q_value_local(mask, guessed, lives, probs_vec, a) for a in acts]
            idx = int(np.argmax(qvals))
            a = acts[idx]
            new_mask, guessed, lives, r, done, repeated, wrong = step_env(word, mask, guessed, a, lives)
            total_guesses += 1
            wrongs += int(wrong)
            repeats += int(repeated)
            mask = new_mask
        win = int(mask == word)
        return {'win': win, 'wrong': wrongs, 'repeated': repeats, 'guesses': total_guesses, 'length': len(word)}
    results_local = [play_game_local(wd) for wd in words]
    success_rate = np.mean([r['win'] for r in results_local]) if results_local else 0.0
    total_wrong = int(np.sum([r['wrong'] for r in results_local]))
    total_repeated = int(np.sum([r['repeated'] for r in results_local]))
    final_score = (success_rate * 2000) - (total_wrong * 5) - (total_repeated * 2)
    return {'games': len(results_local), 'success_rate': success_rate, 'total_wrong': total_wrong, 'total_repeated': total_repeated, 'final_score': final_score, 'results': results_local}
"""Grid search runner. param_grid is a dict mapping param name -> list of values."""
def grid_search(param_grid, max_runs=None, verbose=True):
    keys = list(param_grid.keys())
    combos = list(product(*[param_grid[k] for k in keys]))
    if max_runs is not None:
        combos = combos[:max_runs]
    records = []
    best = None
    start_time = time.time()
    for i, combo in enumerate(combos, 1):
        params = {k: v for k, v in zip(keys, combo)}
        if verbose:
            print(f"Run {i}/{len(combos)}: {params}")
        out = train_agent(params, verbose=False)
        metrics = evaluate_agent(out['w'])
        rec = {'params': params, 'metrics': metrics}
        records.append(rec)
        if best is None or metrics['success_rate'] > best['metrics']['success_rate']:
            best = rec
        if verbose:
            print(f"  success_rate={metrics['success_rate']:.4f}, final_score={metrics['final_score']:.1f}")
    elapsed = time.time() - start_time
    if verbose:
        print(f"Grid search complete: {len(records)} runs in {elapsed:.1f}s. Best success_rate={best['metrics']['success_rate']:.4f} with params={best['params']}")
    return {'records': records, 'best': best}

# %%
# --- Extended randomized grid search with time budget
import random, json, datetime, time
# Define a wider search space (careful: product grows quickly)
param_grid = {
    'EPISODES': [5000, 10000, 15000, 20000],
    'ALPHA': [0.01, 0.03, 0.05, 0.1],
    'EPS_DECAY': [0.99, 0.995, 0.999],
    'EPSILON': [0.1, 0.2, 0.3],
    'seed': [42, 123, 999],
}
# Run configuration
MAX_RUNS = 120  # maximum number of combos to try
TIME_BUDGET_SECS = 30 * 60  # 30 minutes budget
# Build combos and randomize order
keys = list(param_grid.keys())
combos = [dict(zip(keys, vals)) for vals in product(*[param_grid[k] for k in keys])]
random.seed(0)  # deterministic shuffle for reproducibility of experiment order
random.shuffle(combos)
# Trim to MAX_RUNS if there are more
if MAX_RUNS is not None and len(combos) > MAX_RUNS:
    combos = combos[:MAX_RUNS]
print(f"Prepared {len(combos)} runs (max {MAX_RUNS}), time budget {TIME_BUDGET_SECS}s")
# Run searches with time budget and save intermediate results
records = []
best = None
start_time = time.time()
last_save = start_time
SAVE_EVERY = 5  # save a checkpoint every N runs
out_dir = Path('results')
out_dir.mkdir(parents=True, exist_ok=True)
for i, params in enumerate(combos, start=1):
    elapsed = time.time() - start_time
    if elapsed > TIME_BUDGET_SECS:
        print(f"Time budget exceeded after {i-1} runs ({elapsed:.1f}s); stopping.")
        break
    print(f"Run {i}/{len(combos)}: {params} (elapsed {elapsed:.1f}s)")
    run_start = time.time()
    out = train_agent(params, verbose=False)  # trains and returns 'w' and histories
    metrics = evaluate_agent(out['w'])
    run_elapsed = time.time() - run_start
    rec = {'params': params, 'metrics': metrics, 'train_time': run_elapsed, 'timestamp': datetime.datetime.now().isoformat()}
    records.append(rec)
    # track best by success_rate then final_score as tie-breaker
    if best is None or metrics['success_rate'] > best['metrics']['success_rate'] or (metrics['success_rate'] == best['metrics']['success_rate'] and metrics['final_score'] > best['metrics']['final_score']):
        best = {'params': params, 'metrics': metrics, 'w': out['w'].tolist(), 'train_time': run_elapsed, 'timestamp': rec['timestamp']}
        # persist best weights immediately
        ts = int(time.time())
        best_weights_path = out_dir / f"best_weights_{ts}.npz"
        np.savez_compressed(best_weights_path, w=np.array(best['w']), params=json.dumps(params))
        print(f"  New best -> success_rate={metrics['success_rate']:.4f}, saved weights to {best_weights_path}")
    else:
        print(f"  success_rate={metrics['success_rate']:.4f}, final_score={metrics['final_score']:.1f} (train time {run_elapsed:.1f}s)")
    # periodic save of records
    if (i % SAVE_EVERY == 0) or (time.time() - last_save > 300):
        summary_path = out_dir / f"grid_search_partial_{int(time.time())}.json"
        with open(summary_path, 'w', encoding='utf-8') as fp:
            json.dump({'records': [{ 'params': r['params'], 'metrics': r['metrics'], 'train_time': r['train_time'], 'timestamp': r['timestamp']} for r in records], 'best': {'params': best['params'], 'metrics': best['metrics']}}, fp, indent=2, default=str)
        last_save = time.time()
        print(f"  checkpoint saved to {summary_path}")
# Final save
ts_all = int(time.time())
full_path = out_dir / f"grid_search_full_{ts_all}.json"
with open(full_path, 'w', encoding='utf-8') as fp:
    json.dump({'records': [{ 'params': r['params'], 'metrics': r['metrics'], 'train_time': r['train_time'], 'timestamp': r['timestamp']} for r in records], 'best': {'params': best['params'], 'metrics': best['metrics']}}, fp, indent=2, default=str)
print('Grid search complete. Results saved to', full_path)
print('\nBEST RUN:')
print('params =', best['params'])
print('success_rate =', best['metrics']['success_rate'])
print('final_score =', best['metrics']['final_score'])
# Out:
# Prepared 120 runs (max 120), time budget 1800s
# Run 1/120: {'EPISODES': 15000, 'ALPHA': 0.1, 'EPS_DECAY': 0.995, 'EPSILON': 0.2, 'seed': 42} (elapsed 0.0s)
#   New best -> success_rate=0.1870, saved weights to results/best_weights_1762166253.npz
# Run 2/120: {'EPISODES': 5000, 'ALPHA': 0.01, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 42} (elapsed 14.8s)
#   New best -> success_rate=0.1870, saved weights to results/best_weights_1762166253.npz
# Run 2/120: {'EPISODES': 5000, 'ALPHA': 0.01, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 42} (elapsed 14.8s)
#   New best -> success_rate=0.2005, saved weights to results/best_weights_1762166259.npz
# Run 3/120: {'EPISODES': 20000, 'ALPHA': 0.1, 'EPS_DECAY': 0.995, 'EPSILON': 0.3, 'seed': 999} (elapsed 20.4s)
#   New best -> success_rate=0.2005, saved weights to results/best_weights_1762166259.npz
# Run 3/120: {'EPISODES': 20000, 'ALPHA': 0.1, 'EPS_DECAY': 0.995, 'EPSILON': 0.3, 'seed': 999} (elapsed 20.4s)
#   success_rate=0.1925, final_score=-55205.0 (train time 19.6s)
# Run 4/120: {'EPISODES': 15000, 'ALPHA': 0.01, 'EPS_DECAY': 0.999, 'EPSILON': 0.1, 'seed': 42} (elapsed 40.1s)
#   success_rate=0.1925, final_score=-55205.0 (train time 19.6s)
# Run 4/120: {'EPISODES': 15000, 'ALPHA': 0.01, 'EPS_DECAY': 0.999, 'EPSILON': 0.1, 'seed': 42} (elapsed 40.1s)
#   New best -> success_rate=0.2160, saved weights to results/best_weights_1762166294.npz
# Run 5/120: {'EPISODES': 5000, 'ALPHA': 0.03, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 42} (elapsed 55.2s)
#   New best -> success_rate=0.2160, saved weights to results/best_weights_1762166294.npz
# Run 5/120: {'EPISODES': 5000, 'ALPHA': 0.03, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 42} (elapsed 55.2s)
#   New best -> success_rate=0.2195, saved weights to results/best_weights_1762166299.npz
#   checkpoint saved to results/grid_search_partial_1762166299.json
# Run 6/120: {'EPISODES': 15000, 'ALPHA': 0.03, 'EPS_DECAY': 0.995, 'EPSILON': 0.2, 'seed': 999} (elapsed 60.9s)
#   New best -> success_rate=0.2195, saved weights to results/best_weights_1762166299.npz
#   checkpoint saved to results/grid_search_partial_1762166299.json
# Run 6/120: {'EPISODES': 15000, 'ALPHA': 0.03, 'EPS_DECAY': 0.995, 'EPSILON': 0.2, 'seed': 999} (elapsed 60.9s)
#   New best -> success_rate=0.2230, saved weights to results/best_weights_1762166314.npz
# Run 7/120: {'EPISODES': 5000, 'ALPHA': 0.03, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 123} (elapsed 75.9s)
#   New best -> success_rate=0.2230, saved weights to results/best_weights_1762166314.npz
# Run 7/120: {'EPISODES': 5000, 'ALPHA': 0.03, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 123} (elapsed 75.9s)
#   success_rate=0.2180, final_score=-54929.0 (train time 5.7s)
# Run 8/120: {'EPISODES': 10000, 'ALPHA': 0.1, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 42} (elapsed 81.6s)
#   success_rate=0.2180, final_score=-54929.0 (train time 5.7s)
# Run 8/120: {'EPISODES': 10000, 'ALPHA': 0.1, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 42} (elapsed 81.6s)
#   success_rate=0.2160, final_score=-54773.0 (train time 10.3s)
# Run 9/120: {'EPISODES': 5000, 'ALPHA': 0.05, 'EPS_DECAY': 0.995, 'EPSILON': 0.3, 'seed': 42} (elapsed 91.9s)
#   success_rate=0.2160, final_score=-54773.0 (train time 10.3s)
# Run 9/120: {'EPISODES': 5000, 'ALPHA': 0.05, 'EPS_DECAY': 0.995, 'EPSILON': 0.3, 'seed': 42} (elapsed 91.9s)
#   success_rate=0.1990, final_score=-55392.0 (train time 5.7s)
# Run 10/120: {'EPISODES': 10000, 'ALPHA': 0.1, 'EPS_DECAY': 0.999, 'EPSILON': 0.1, 'seed': 999} (elapsed 97.6s)
#   success_rate=0.1990, final_score=-55392.0 (train time 5.7s)
# Run 10/120: {'EPISODES': 10000, 'ALPHA': 0.1, 'EPS_DECAY': 0.999, 'EPSILON': 0.1, 'seed': 999} (elapsed 97.6s)
#   success_rate=0.2050, final_score=-55275.0 (train time 10.3s)
#   checkpoint saved to results/grid_search_partial_1762166346.json
# Run 11/120: {'EPISODES': 15000, 'ALPHA': 0.05, 'EPS_DECAY': 0.99, 'EPSILON': 0.3, 'seed': 123} (elapsed 107.9s)
#   success_rate=0.2050, final_score=-55275.0 (train time 10.3s)
#   checkpoint saved to results/grid_search_partial_1762166346.json
# Run 11/120: {'EPISODES': 15000, 'ALPHA': 0.05, 'EPS_DECAY': 0.99, 'EPSILON': 0.3, 'seed': 123} (elapsed 107.9s)
#   success_rate=0.2035, final_score=-55333.0 (train time 15.0s)
# Run 12/120: {'EPISODES': 15000, 'ALPHA': 0.03, 'EPS_DECAY': 0.999, 'EPSILON': 0.2, 'seed': 123} (elapsed 123.0s)
#   success_rate=0.2035, final_score=-55333.0 (train time 15.0s)
# Run 12/120: {'EPISODES': 15000, 'ALPHA': 0.03, 'EPS_DECAY': 0.999, 'EPSILON': 0.2, 'seed': 123} (elapsed 123.0s)
#   success_rate=0.2065, final_score=-54972.0 (train time 14.9s)
# Run 13/120: {'EPISODES': 15000, 'ALPHA': 0.05, 'EPS_DECAY': 0.999, 'EPSILON': 0.1, 'seed': 42} (elapsed 137.9s)
#   success_rate=0.2065, final_score=-54972.0 (train time 14.9s)
# Run 13/120: {'EPISODES': 15000, 'ALPHA': 0.05, 'EPS_DECAY': 0.999, 'EPSILON': 0.1, 'seed': 42} (elapsed 137.9s)
#   success_rate=0.2185, final_score=-54573.0 (train time 14.9s)
# Run 14/120: {'EPISODES': 20000, 'ALPHA': 0.01, 'EPS_DECAY': 0.999, 'EPSILON': 0.1, 'seed': 123} (elapsed 152.8s)
#   success_rate=0.2185, final_score=-54573.0 (train time 14.9s)
# Run 14/120: {'EPISODES': 20000, 'ALPHA': 0.01, 'EPS_DECAY': 0.999, 'EPSILON': 0.1, 'seed': 123} (elapsed 152.8s)
#   success_rate=0.2140, final_score=-54767.0 (train time 19.7s)
# Run 15/120: {'EPISODES': 5000, 'ALPHA': 0.03, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 999} (elapsed 172.5s)
#   success_rate=0.2140, final_score=-54767.0 (train time 19.7s)
# Run 15/120: {'EPISODES': 5000, 'ALPHA': 0.03, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 999} (elapsed 172.5s)
#   success_rate=0.2225, final_score=-54650.0 (train time 5.6s)
#   checkpoint saved to results/grid_search_partial_1762166417.json
# Run 16/120: {'EPISODES': 10000, 'ALPHA': 0.03, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 42} (elapsed 178.3s)
#   success_rate=0.2225, final_score=-54650.0 (train time 5.6s)
#   checkpoint saved to results/grid_search_partial_1762166417.json
# Run 16/120: {'EPISODES': 10000, 'ALPHA': 0.03, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 42} (elapsed 178.3s)
#   success_rate=0.2070, final_score=-55041.0 (train time 10.3s)
# Run 17/120: {'EPISODES': 5000, 'ALPHA': 0.05, 'EPS_DECAY': 0.99, 'EPSILON': 0.3, 'seed': 999} (elapsed 188.6s)
#   success_rate=0.2070, final_score=-55041.0 (train time 10.3s)
# Run 17/120: {'EPISODES': 5000, 'ALPHA': 0.05, 'EPS_DECAY': 0.99, 'EPSILON': 0.3, 'seed': 999} (elapsed 188.6s)
#   success_rate=0.2145, final_score=-54916.0 (train time 5.6s)
# Run 18/120: {'EPISODES': 5000, 'ALPHA': 0.1, 'EPS_DECAY': 0.995, 'EPSILON': 0.3, 'seed': 999} (elapsed 194.2s)
#   success_rate=0.2145, final_score=-54916.0 (train time 5.6s)
# Run 18/120: {'EPISODES': 5000, 'ALPHA': 0.1, 'EPS_DECAY': 0.995, 'EPSILON': 0.3, 'seed': 999} (elapsed 194.2s)
#   New best -> success_rate=0.2230, saved weights to results/best_weights_1762166438.npz
# Run 19/120: {'EPISODES': 10000, 'ALPHA': 0.1, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 999} (elapsed 199.9s)
#   New best -> success_rate=0.2230, saved weights to results/best_weights_1762166438.npz
# Run 19/120: {'EPISODES': 10000, 'ALPHA': 0.1, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 999} (elapsed 199.9s)
#   success_rate=0.2230, final_score=-54759.0 (train time 10.2s)
# Run 20/120: {'EPISODES': 5000, 'ALPHA': 0.03, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 999} (elapsed 210.1s)
#   success_rate=0.2230, final_score=-54759.0 (train time 10.2s)
# Run 20/120: {'EPISODES': 5000, 'ALPHA': 0.03, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 999} (elapsed 210.1s)
#   success_rate=0.2170, final_score=-54911.0 (train time 5.6s)
#   checkpoint saved to results/grid_search_partial_1762166454.json
# Run 21/120: {'EPISODES': 10000, 'ALPHA': 0.05, 'EPS_DECAY': 0.995, 'EPSILON': 0.2, 'seed': 123} (elapsed 215.9s)
#   success_rate=0.2170, final_score=-54911.0 (train time 5.6s)
#   checkpoint saved to results/grid_search_partial_1762166454.json
# Run 21/120: {'EPISODES': 10000, 'ALPHA': 0.05, 'EPS_DECAY': 0.995, 'EPSILON': 0.2, 'seed': 123} (elapsed 215.9s)
#   New best -> success_rate=0.2235, saved weights to results/best_weights_1762166465.npz
# Run 22/120: {'EPISODES': 15000, 'ALPHA': 0.01, 'EPS_DECAY': 0.99, 'EPSILON': 0.3, 'seed': 999} (elapsed 226.2s)
#   New best -> success_rate=0.2235, saved weights to results/best_weights_1762166465.npz
# Run 22/120: {'EPISODES': 15000, 'ALPHA': 0.01, 'EPS_DECAY': 0.99, 'EPSILON': 0.3, 'seed': 999} (elapsed 226.2s)
#   success_rate=0.2205, final_score=-54774.0 (train time 14.9s)
# Run 23/120: {'EPISODES': 10000, 'ALPHA': 0.01, 'EPS_DECAY': 0.995, 'EPSILON': 0.2, 'seed': 123} (elapsed 241.1s)
#   success_rate=0.2205, final_score=-54774.0 (train time 14.9s)
# Run 23/120: {'EPISODES': 10000, 'ALPHA': 0.01, 'EPS_DECAY': 0.995, 'EPSILON': 0.2, 'seed': 123} (elapsed 241.1s)
#   success_rate=0.2135, final_score=-54798.0 (train time 10.3s)
# Run 24/120: {'EPISODES': 15000, 'ALPHA': 0.01, 'EPS_DECAY': 0.995, 'EPSILON': 0.3, 'seed': 999} (elapsed 251.4s)
#   success_rate=0.2135, final_score=-54798.0 (train time 10.3s)
# Run 24/120: {'EPISODES': 15000, 'ALPHA': 0.01, 'EPS_DECAY': 0.995, 'EPSILON': 0.3, 'seed': 999} (elapsed 251.4s)
#   success_rate=0.2225, final_score=-54835.0 (train time 15.0s)
# Run 25/120: {'EPISODES': 20000, 'ALPHA': 0.03, 'EPS_DECAY': 0.995, 'EPSILON': 0.2, 'seed': 123} (elapsed 266.4s)
#   success_rate=0.2225, final_score=-54835.0 (train time 15.0s)
# Run 25/120: {'EPISODES': 20000, 'ALPHA': 0.03, 'EPS_DECAY': 0.995, 'EPSILON': 0.2, 'seed': 123} (elapsed 266.4s)
#   success_rate=0.2175, final_score=-54835.0 (train time 19.5s)
#   checkpoint saved to results/grid_search_partial_1762166524.json
# Run 26/120: {'EPISODES': 10000, 'ALPHA': 0.1, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 999} (elapsed 286.1s)
#   success_rate=0.2175, final_score=-54835.0 (train time 19.5s)
#   checkpoint saved to results/grid_search_partial_1762166524.json
# Run 26/120: {'EPISODES': 10000, 'ALPHA': 0.1, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 999} (elapsed 286.1s)
#   success_rate=0.2220, final_score=-54726.0 (train time 10.4s)
# Run 27/120: {'EPISODES': 15000, 'ALPHA': 0.05, 'EPS_DECAY': 0.995, 'EPSILON': 0.2, 'seed': 999} (elapsed 296.5s)
#   success_rate=0.2220, final_score=-54726.0 (train time 10.4s)
# Run 27/120: {'EPISODES': 15000, 'ALPHA': 0.05, 'EPS_DECAY': 0.995, 'EPSILON': 0.2, 'seed': 999} (elapsed 296.5s)
#   success_rate=0.1905, final_score=-55464.0 (train time 15.0s)
# Run 28/120: {'EPISODES': 5000, 'ALPHA': 0.05, 'EPS_DECAY': 0.995, 'EPSILON': 0.3, 'seed': 123} (elapsed 311.5s)
#   success_rate=0.1905, final_score=-55464.0 (train time 15.0s)
# Run 28/120: {'EPISODES': 5000, 'ALPHA': 0.05, 'EPS_DECAY': 0.995, 'EPSILON': 0.3, 'seed': 123} (elapsed 311.5s)
#   success_rate=0.2145, final_score=-54851.0 (train time 5.7s)
# Run 29/120: {'EPISODES': 5000, 'ALPHA': 0.05, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 42} (elapsed 317.2s)
#   success_rate=0.2145, final_score=-54851.0 (train time 5.7s)
# Run 29/120: {'EPISODES': 5000, 'ALPHA': 0.05, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 42} (elapsed 317.2s)
#   success_rate=0.1970, final_score=-55481.0 (train time 5.6s)
# Run 30/120: {'EPISODES': 20000, 'ALPHA': 0.01, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 42} (elapsed 322.8s)
#   success_rate=0.1970, final_score=-55481.0 (train time 5.6s)
# Run 30/120: {'EPISODES': 20000, 'ALPHA': 0.01, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 42} (elapsed 322.8s)
#   success_rate=0.2050, final_score=-55075.0 (train time 19.6s)
#   success_rate=0.2050, final_score=-55075.0 (train time 19.6s)
#   checkpoint saved to results/grid_search_partial_1762166581.json
# Run 31/120: {'EPISODES': 20000, 'ALPHA': 0.1, 'EPS_DECAY': 0.999, 'EPSILON': 0.1, 'seed': 123} (elapsed 342.6s)
#   checkpoint saved to results/grid_search_partial_1762166581.json
# Run 31/120: {'EPISODES': 20000, 'ALPHA': 0.1, 'EPS_DECAY': 0.999, 'EPSILON': 0.1, 'seed': 123} (elapsed 342.6s)
#   success_rate=0.1930, final_score=-55714.0 (train time 19.8s)
# Run 32/120: {'EPISODES': 15000, 'ALPHA': 0.01, 'EPS_DECAY': 0.999, 'EPSILON': 0.2, 'seed': 42} (elapsed 362.4s)
#   success_rate=0.1930, final_score=-55714.0 (train time 19.8s)
# Run 32/120: {'EPISODES': 15000, 'ALPHA': 0.01, 'EPS_DECAY': 0.999, 'EPSILON': 0.2, 'seed': 42} (elapsed 362.4s)
#   success_rate=0.2230, final_score=-54754.0 (train time 14.9s)
# Run 33/120: {'EPISODES': 20000, 'ALPHA': 0.01, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 999} (elapsed 377.3s)
#   success_rate=0.2230, final_score=-54754.0 (train time 14.9s)
# Run 33/120: {'EPISODES': 20000, 'ALPHA': 0.01, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 999} (elapsed 377.3s)
#   success_rate=0.2115, final_score=-54882.0 (train time 19.6s)
# Run 34/120: {'EPISODES': 20000, 'ALPHA': 0.01, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 123} (elapsed 396.9s)
#   success_rate=0.2115, final_score=-54882.0 (train time 19.6s)
# Run 34/120: {'EPISODES': 20000, 'ALPHA': 0.01, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 123} (elapsed 396.9s)
#   success_rate=0.2145, final_score=-54701.0 (train time 19.7s)
# Run 35/120: {'EPISODES': 15000, 'ALPHA': 0.03, 'EPS_DECAY': 0.999, 'EPSILON': 0.1, 'seed': 123} (elapsed 416.6s)
#   success_rate=0.2145, final_score=-54701.0 (train time 19.7s)
# Run 35/120: {'EPISODES': 15000, 'ALPHA': 0.03, 'EPS_DECAY': 0.999, 'EPSILON': 0.1, 'seed': 123} (elapsed 416.6s)
#   success_rate=0.2130, final_score=-54929.0 (train time 15.0s)
#   success_rate=0.2130, final_score=-54929.0 (train time 15.0s)
#   checkpoint saved to results/grid_search_partial_1762166670.json
# Run 36/120: {'EPISODES': 20000, 'ALPHA': 0.03, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 999} (elapsed 431.9s)
#   checkpoint saved to results/grid_search_partial_1762166670.json
# Run 36/120: {'EPISODES': 20000, 'ALPHA': 0.03, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 999} (elapsed 431.9s)
#   New best -> success_rate=0.2235, saved weights to results/best_weights_1762166690.npz
# Run 37/120: {'EPISODES': 5000, 'ALPHA': 0.1, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 42} (elapsed 451.7s)
#   New best -> success_rate=0.2235, saved weights to results/best_weights_1762166690.npz
# Run 37/120: {'EPISODES': 5000, 'ALPHA': 0.1, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 42} (elapsed 451.7s)
#   success_rate=0.1890, final_score=-55477.0 (train time 5.7s)
# Run 38/120: {'EPISODES': 5000, 'ALPHA': 0.03, 'EPS_DECAY': 0.995, 'EPSILON': 0.1, 'seed': 999} (elapsed 457.4s)
#   success_rate=0.1890, final_score=-55477.0 (train time 5.7s)
# Run 38/120: {'EPISODES': 5000, 'ALPHA': 0.03, 'EPS_DECAY': 0.995, 'EPSILON': 0.1, 'seed': 999} (elapsed 457.4s)
#   success_rate=0.2190, final_score=-54962.0 (train time 5.7s)
# Run 39/120: {'EPISODES': 5000, 'ALPHA': 0.01, 'EPS_DECAY': 0.99, 'EPSILON': 0.3, 'seed': 42} (elapsed 463.1s)
#   success_rate=0.2190, final_score=-54962.0 (train time 5.7s)
# Run 39/120: {'EPISODES': 5000, 'ALPHA': 0.01, 'EPS_DECAY': 0.99, 'EPSILON': 0.3, 'seed': 42} (elapsed 463.1s)
#   success_rate=0.2135, final_score=-55228.0 (train time 5.6s)
# Run 40/120: {'EPISODES': 20000, 'ALPHA': 0.05, 'EPS_DECAY': 0.999, 'EPSILON': 0.1, 'seed': 123} (elapsed 468.7s)
#   success_rate=0.2135, final_score=-55228.0 (train time 5.6s)
# Run 40/120: {'EPISODES': 20000, 'ALPHA': 0.05, 'EPS_DECAY': 0.999, 'EPSILON': 0.1, 'seed': 123} (elapsed 468.7s)
#   success_rate=0.1950, final_score=-55235.0 (train time 20.0s)
#   success_rate=0.1950, final_score=-55235.0 (train time 20.0s)
#   checkpoint saved to results/grid_search_partial_1762166727.json
# Run 41/120: {'EPISODES': 5000, 'ALPHA': 0.05, 'EPS_DECAY': 0.995, 'EPSILON': 0.1, 'seed': 999} (elapsed 489.0s)
#   checkpoint saved to results/grid_search_partial_1762166727.json
# Run 41/120: {'EPISODES': 5000, 'ALPHA': 0.05, 'EPS_DECAY': 0.995, 'EPSILON': 0.1, 'seed': 999} (elapsed 489.0s)
#   success_rate=0.1950, final_score=-55455.0 (train time 5.8s)
# Run 42/120: {'EPISODES': 10000, 'ALPHA': 0.03, 'EPS_DECAY': 0.99, 'EPSILON': 0.3, 'seed': 123} (elapsed 494.8s)
#   success_rate=0.1950, final_score=-55455.0 (train time 5.8s)
# Run 42/120: {'EPISODES': 10000, 'ALPHA': 0.03, 'EPS_DECAY': 0.99, 'EPSILON': 0.3, 'seed': 123} (elapsed 494.8s)
#   success_rate=0.2050, final_score=-55035.0 (train time 10.4s)
# Run 43/120: {'EPISODES': 5000, 'ALPHA': 0.05, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 999} (elapsed 505.2s)
#   success_rate=0.2050, final_score=-55035.0 (train time 10.4s)
# Run 43/120: {'EPISODES': 5000, 'ALPHA': 0.05, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 999} (elapsed 505.2s)
#   success_rate=0.2085, final_score=-55403.0 (train time 5.7s)
# Run 44/120: {'EPISODES': 5000, 'ALPHA': 0.05, 'EPS_DECAY': 0.995, 'EPSILON': 0.2, 'seed': 123} (elapsed 510.9s)
#   success_rate=0.2085, final_score=-55403.0 (train time 5.7s)
# Run 44/120: {'EPISODES': 5000, 'ALPHA': 0.05, 'EPS_DECAY': 0.995, 'EPSILON': 0.2, 'seed': 123} (elapsed 510.9s)
#   success_rate=0.2180, final_score=-54879.0 (train time 5.7s)
# Run 45/120: {'EPISODES': 10000, 'ALPHA': 0.1, 'EPS_DECAY': 0.999, 'EPSILON': 0.2, 'seed': 42} (elapsed 516.6s)
#   success_rate=0.2180, final_score=-54879.0 (train time 5.7s)
# Run 45/120: {'EPISODES': 10000, 'ALPHA': 0.1, 'EPS_DECAY': 0.999, 'EPSILON': 0.2, 'seed': 42} (elapsed 516.6s)
#   success_rate=0.1915, final_score=-55437.0 (train time 10.4s)
#   success_rate=0.1915, final_score=-55437.0 (train time 10.4s)
#   checkpoint saved to results/grid_search_partial_1762166765.json
# Run 46/120: {'EPISODES': 5000, 'ALPHA': 0.1, 'EPS_DECAY': 0.995, 'EPSILON': 0.2, 'seed': 42} (elapsed 527.3s)
#   checkpoint saved to results/grid_search_partial_1762166765.json
# Run 46/120: {'EPISODES': 5000, 'ALPHA': 0.1, 'EPS_DECAY': 0.995, 'EPSILON': 0.2, 'seed': 42} (elapsed 527.3s)
#   success_rate=0.2020, final_score=-55376.0 (train time 5.8s)
# Run 47/120: {'EPISODES': 20000, 'ALPHA': 0.1, 'EPS_DECAY': 0.995, 'EPSILON': 0.2, 'seed': 999} (elapsed 533.1s)
#   success_rate=0.2020, final_score=-55376.0 (train time 5.8s)
# Run 47/120: {'EPISODES': 20000, 'ALPHA': 0.1, 'EPS_DECAY': 0.995, 'EPSILON': 0.2, 'seed': 999} (elapsed 533.1s)
#   success_rate=0.1940, final_score=-55532.0 (train time 19.8s)
# Run 48/120: {'EPISODES': 20000, 'ALPHA': 0.1, 'EPS_DECAY': 0.995, 'EPSILON': 0.2, 'seed': 42} (elapsed 552.8s)
#   success_rate=0.1940, final_score=-55532.0 (train time 19.8s)
# Run 48/120: {'EPISODES': 20000, 'ALPHA': 0.1, 'EPS_DECAY': 0.995, 'EPSILON': 0.2, 'seed': 42} (elapsed 552.8s)
#   success_rate=0.1940, final_score=-55322.0 (train time 19.6s)
# Run 49/120: {'EPISODES': 10000, 'ALPHA': 0.01, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 999} (elapsed 572.5s)
#   success_rate=0.1940, final_score=-55322.0 (train time 19.6s)
# Run 49/120: {'EPISODES': 10000, 'ALPHA': 0.01, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 999} (elapsed 572.5s)
#   success_rate=0.2120, final_score=-55091.0 (train time 10.4s)
# Run 50/120: {'EPISODES': 5000, 'ALPHA': 0.01, 'EPS_DECAY': 0.995, 'EPSILON': 0.3, 'seed': 42} (elapsed 582.9s)
#   success_rate=0.2120, final_score=-55091.0 (train time 10.4s)
# Run 50/120: {'EPISODES': 5000, 'ALPHA': 0.01, 'EPS_DECAY': 0.995, 'EPSILON': 0.3, 'seed': 42} (elapsed 582.9s)
#   success_rate=0.1955, final_score=-55189.0 (train time 5.7s)
#   success_rate=0.1955, final_score=-55189.0 (train time 5.7s)
#   checkpoint saved to results/grid_search_partial_1762166827.json
# Run 51/120: {'EPISODES': 10000, 'ALPHA': 0.1, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 123} (elapsed 589.0s)
#   checkpoint saved to results/grid_search_partial_1762166827.json
# Run 51/120: {'EPISODES': 10000, 'ALPHA': 0.1, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 123} (elapsed 589.0s)
#   success_rate=0.1590, final_score=-56347.0 (train time 10.4s)
# Run 52/120: {'EPISODES': 15000, 'ALPHA': 0.03, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 123} (elapsed 599.4s)
#   success_rate=0.1590, final_score=-56347.0 (train time 10.4s)
# Run 52/120: {'EPISODES': 15000, 'ALPHA': 0.03, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 123} (elapsed 599.4s)
#   success_rate=0.2195, final_score=-54601.0 (train time 15.1s)
# Run 53/120: {'EPISODES': 20000, 'ALPHA': 0.05, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 123} (elapsed 614.4s)
#   success_rate=0.2195, final_score=-54601.0 (train time 15.1s)
# Run 53/120: {'EPISODES': 20000, 'ALPHA': 0.05, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 123} (elapsed 614.4s)
#   success_rate=0.2185, final_score=-54863.0 (train time 19.7s)
# Run 54/120: {'EPISODES': 5000, 'ALPHA': 0.1, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 999} (elapsed 634.2s)
#   success_rate=0.2185, final_score=-54863.0 (train time 19.7s)
# Run 54/120: {'EPISODES': 5000, 'ALPHA': 0.1, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 999} (elapsed 634.2s)
#   success_rate=0.2085, final_score=-54903.0 (train time 5.7s)
# Run 55/120: {'EPISODES': 10000, 'ALPHA': 0.05, 'EPS_DECAY': 0.999, 'EPSILON': 0.1, 'seed': 42} (elapsed 639.8s)
#   success_rate=0.2085, final_score=-54903.0 (train time 5.7s)
# Run 55/120: {'EPISODES': 10000, 'ALPHA': 0.05, 'EPS_DECAY': 0.999, 'EPSILON': 0.1, 'seed': 42} (elapsed 639.8s)
#   success_rate=0.2165, final_score=-54637.0 (train time 10.4s)
#   success_rate=0.2165, final_score=-54637.0 (train time 10.4s)
#   checkpoint saved to results/grid_search_partial_1762166889.json
# Run 56/120: {'EPISODES': 20000, 'ALPHA': 0.01, 'EPS_DECAY': 0.999, 'EPSILON': 0.2, 'seed': 123} (elapsed 650.6s)
#   checkpoint saved to results/grid_search_partial_1762166889.json
# Run 56/120: {'EPISODES': 20000, 'ALPHA': 0.01, 'EPS_DECAY': 0.999, 'EPSILON': 0.2, 'seed': 123} (elapsed 650.6s)
#   New best -> success_rate=0.2255, saved weights to results/best_weights_1762166909.npz
# Run 57/120: {'EPISODES': 20000, 'ALPHA': 0.1, 'EPS_DECAY': 0.999, 'EPSILON': 0.2, 'seed': 123} (elapsed 670.5s)
#   New best -> success_rate=0.2255, saved weights to results/best_weights_1762166909.npz
# Run 57/120: {'EPISODES': 20000, 'ALPHA': 0.1, 'EPS_DECAY': 0.999, 'EPSILON': 0.2, 'seed': 123} (elapsed 670.5s)
#   success_rate=0.2185, final_score=-54898.0 (train time 19.7s)
# Run 58/120: {'EPISODES': 20000, 'ALPHA': 0.1, 'EPS_DECAY': 0.999, 'EPSILON': 0.2, 'seed': 42} (elapsed 690.2s)
#   success_rate=0.2185, final_score=-54898.0 (train time 19.7s)
# Run 58/120: {'EPISODES': 20000, 'ALPHA': 0.1, 'EPS_DECAY': 0.999, 'EPSILON': 0.2, 'seed': 42} (elapsed 690.2s)
#   success_rate=0.2080, final_score=-55094.0 (train time 19.8s)
# Run 59/120: {'EPISODES': 15000, 'ALPHA': 0.1, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 42} (elapsed 710.0s)
#   success_rate=0.2080, final_score=-55094.0 (train time 19.8s)
# Run 59/120: {'EPISODES': 15000, 'ALPHA': 0.1, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 42} (elapsed 710.0s)
#   success_rate=0.2245, final_score=-54876.0 (train time 15.2s)
# Run 60/120: {'EPISODES': 15000, 'ALPHA': 0.05, 'EPS_DECAY': 0.999, 'EPSILON': 0.1, 'seed': 123} (elapsed 725.2s)
#   success_rate=0.2245, final_score=-54876.0 (train time 15.2s)
# Run 60/120: {'EPISODES': 15000, 'ALPHA': 0.05, 'EPS_DECAY': 0.999, 'EPSILON': 0.1, 'seed': 123} (elapsed 725.2s)
#   success_rate=0.2220, final_score=-54801.0 (train time 15.0s)
#   success_rate=0.2220, final_score=-54801.0 (train time 15.0s)
#   checkpoint saved to results/grid_search_partial_1762166979.json
# Run 61/120: {'EPISODES': 10000, 'ALPHA': 0.05, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 999} (elapsed 740.6s)
#   checkpoint saved to results/grid_search_partial_1762166979.json
# Run 61/120: {'EPISODES': 10000, 'ALPHA': 0.05, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 999} (elapsed 740.6s)
#   success_rate=0.2230, final_score=-54869.0 (train time 10.4s)
# Run 62/120: {'EPISODES': 10000, 'ALPHA': 0.1, 'EPS_DECAY': 0.995, 'EPSILON': 0.3, 'seed': 123} (elapsed 751.0s)
#   success_rate=0.2230, final_score=-54869.0 (train time 10.4s)
# Run 62/120: {'EPISODES': 10000, 'ALPHA': 0.1, 'EPS_DECAY': 0.995, 'EPSILON': 0.3, 'seed': 123} (elapsed 751.0s)
#   success_rate=0.1705, final_score=-56094.0 (train time 10.3s)
# Run 63/120: {'EPISODES': 5000, 'ALPHA': 0.1, 'EPS_DECAY': 0.99, 'EPSILON': 0.3, 'seed': 999} (elapsed 761.4s)
#   success_rate=0.1705, final_score=-56094.0 (train time 10.3s)
# Run 63/120: {'EPISODES': 5000, 'ALPHA': 0.1, 'EPS_DECAY': 0.99, 'EPSILON': 0.3, 'seed': 999} (elapsed 761.4s)
#   success_rate=0.2145, final_score=-55041.0 (train time 5.7s)
# Run 64/120: {'EPISODES': 10000, 'ALPHA': 0.03, 'EPS_DECAY': 0.995, 'EPSILON': 0.3, 'seed': 42} (elapsed 767.1s)
#   success_rate=0.2145, final_score=-55041.0 (train time 5.7s)
# Run 64/120: {'EPISODES': 10000, 'ALPHA': 0.03, 'EPS_DECAY': 0.995, 'EPSILON': 0.3, 'seed': 42} (elapsed 767.1s)
#   success_rate=0.2185, final_score=-54603.0 (train time 10.4s)
# Run 65/120: {'EPISODES': 5000, 'ALPHA': 0.01, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 123} (elapsed 777.4s)
#   success_rate=0.2185, final_score=-54603.0 (train time 10.4s)
# Run 65/120: {'EPISODES': 5000, 'ALPHA': 0.01, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 123} (elapsed 777.4s)
#   success_rate=0.2155, final_score=-54894.0 (train time 5.7s)
#   success_rate=0.2155, final_score=-54894.0 (train time 5.7s)
#   checkpoint saved to results/grid_search_partial_1762167022.json
# Run 66/120: {'EPISODES': 20000, 'ALPHA': 0.01, 'EPS_DECAY': 0.995, 'EPSILON': 0.1, 'seed': 999} (elapsed 783.7s)
#   checkpoint saved to results/grid_search_partial_1762167022.json
# Run 66/120: {'EPISODES': 20000, 'ALPHA': 0.01, 'EPS_DECAY': 0.995, 'EPSILON': 0.1, 'seed': 999} (elapsed 783.7s)
#   success_rate=0.2210, final_score=-54758.0 (train time 19.9s)
# Run 67/120: {'EPISODES': 15000, 'ALPHA': 0.03, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 42} (elapsed 803.6s)
#   success_rate=0.2210, final_score=-54758.0 (train time 19.9s)
# Run 67/120: {'EPISODES': 15000, 'ALPHA': 0.03, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 42} (elapsed 803.6s)
#   success_rate=0.2210, final_score=-54658.0 (train time 15.1s)
# Run 68/120: {'EPISODES': 15000, 'ALPHA': 0.01, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 123} (elapsed 818.6s)
#   success_rate=0.2210, final_score=-54658.0 (train time 15.1s)
# Run 68/120: {'EPISODES': 15000, 'ALPHA': 0.01, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 123} (elapsed 818.6s)
#   success_rate=0.2150, final_score=-54780.0 (train time 15.1s)
# Run 69/120: {'EPISODES': 15000, 'ALPHA': 0.01, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 42} (elapsed 833.7s)
#   success_rate=0.2150, final_score=-54780.0 (train time 15.1s)
# Run 69/120: {'EPISODES': 15000, 'ALPHA': 0.01, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 42} (elapsed 833.7s)
#   success_rate=0.2240, final_score=-54697.0 (train time 15.0s)
# Run 70/120: {'EPISODES': 20000, 'ALPHA': 0.05, 'EPS_DECAY': 0.995, 'EPSILON': 0.3, 'seed': 42} (elapsed 848.7s)
#   success_rate=0.2240, final_score=-54697.0 (train time 15.0s)
# Run 70/120: {'EPISODES': 20000, 'ALPHA': 0.05, 'EPS_DECAY': 0.995, 'EPSILON': 0.3, 'seed': 42} (elapsed 848.7s)
#   success_rate=0.2020, final_score=-55306.0 (train time 19.7s)
#   success_rate=0.2020, final_score=-55306.0 (train time 19.7s)
#   checkpoint saved to results/grid_search_partial_1762167107.json
# Run 71/120: {'EPISODES': 20000, 'ALPHA': 0.01, 'EPS_DECAY': 0.995, 'EPSILON': 0.3, 'seed': 42} (elapsed 869.0s)
#   checkpoint saved to results/grid_search_partial_1762167107.json
# Run 71/120: {'EPISODES': 20000, 'ALPHA': 0.01, 'EPS_DECAY': 0.995, 'EPSILON': 0.3, 'seed': 42} (elapsed 869.0s)
#   success_rate=0.2250, final_score=-54630.0 (train time 19.9s)
# Run 72/120: {'EPISODES': 15000, 'ALPHA': 0.03, 'EPS_DECAY': 0.99, 'EPSILON': 0.3, 'seed': 999} (elapsed 888.9s)
#   success_rate=0.2250, final_score=-54630.0 (train time 19.9s)
# Run 72/120: {'EPISODES': 15000, 'ALPHA': 0.03, 'EPS_DECAY': 0.99, 'EPSILON': 0.3, 'seed': 999} (elapsed 888.9s)
#   New best -> success_rate=0.2325, saved weights to results/best_weights_1762167142.npz
# Run 73/120: {'EPISODES': 10000, 'ALPHA': 0.01, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 42} (elapsed 904.0s)
#   New best -> success_rate=0.2325, saved weights to results/best_weights_1762167142.npz
# Run 73/120: {'EPISODES': 10000, 'ALPHA': 0.01, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 42} (elapsed 904.0s)
#   success_rate=0.2215, final_score=-54892.0 (train time 10.6s)
# Run 74/120: {'EPISODES': 5000, 'ALPHA': 0.01, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 123} (elapsed 914.6s)
#   success_rate=0.2215, final_score=-54892.0 (train time 10.6s)
# Run 74/120: {'EPISODES': 5000, 'ALPHA': 0.01, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 123} (elapsed 914.6s)
#   success_rate=0.1965, final_score=-55357.0 (train time 5.7s)
# Run 75/120: {'EPISODES': 15000, 'ALPHA': 0.05, 'EPS_DECAY': 0.995, 'EPSILON': 0.3, 'seed': 42} (elapsed 920.3s)
#   success_rate=0.1965, final_score=-55357.0 (train time 5.7s)
# Run 75/120: {'EPISODES': 15000, 'ALPHA': 0.05, 'EPS_DECAY': 0.995, 'EPSILON': 0.3, 'seed': 42} (elapsed 920.3s)
#   success_rate=0.2170, final_score=-54686.0 (train time 15.1s)
#   success_rate=0.2170, final_score=-54686.0 (train time 15.1s)
#   checkpoint saved to results/grid_search_partial_1762167174.json
# Run 76/120: {'EPISODES': 20000, 'ALPHA': 0.1, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 42} (elapsed 935.9s)
#   checkpoint saved to results/grid_search_partial_1762167174.json
# Run 76/120: {'EPISODES': 20000, 'ALPHA': 0.1, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 42} (elapsed 935.9s)
#   success_rate=0.1950, final_score=-55290.0 (train time 20.1s)
# Run 77/120: {'EPISODES': 10000, 'ALPHA': 0.01, 'EPS_DECAY': 0.999, 'EPSILON': 0.2, 'seed': 999} (elapsed 956.0s)
#   success_rate=0.1950, final_score=-55290.0 (train time 20.1s)
# Run 77/120: {'EPISODES': 10000, 'ALPHA': 0.01, 'EPS_DECAY': 0.999, 'EPSILON': 0.2, 'seed': 999} (elapsed 956.0s)
#   success_rate=0.2205, final_score=-54629.0 (train time 10.6s)
# Run 78/120: {'EPISODES': 20000, 'ALPHA': 0.01, 'EPS_DECAY': 0.99, 'EPSILON': 0.3, 'seed': 999} (elapsed 966.7s)
#   success_rate=0.2205, final_score=-54629.0 (train time 10.6s)
# Run 78/120: {'EPISODES': 20000, 'ALPHA': 0.01, 'EPS_DECAY': 0.99, 'EPSILON': 0.3, 'seed': 999} (elapsed 966.7s)
#   success_rate=0.2085, final_score=-54988.0 (train time 20.0s)
# Run 79/120: {'EPISODES': 5000, 'ALPHA': 0.01, 'EPS_DECAY': 0.999, 'EPSILON': 0.2, 'seed': 123} (elapsed 986.6s)
#   success_rate=0.2085, final_score=-54988.0 (train time 20.0s)
# Run 79/120: {'EPISODES': 5000, 'ALPHA': 0.01, 'EPS_DECAY': 0.999, 'EPSILON': 0.2, 'seed': 123} (elapsed 986.6s)
#   success_rate=0.2110, final_score=-55013.0 (train time 5.7s)
# Run 80/120: {'EPISODES': 5000, 'ALPHA': 0.05, 'EPS_DECAY': 0.995, 'EPSILON': 0.2, 'seed': 999} (elapsed 992.3s)
#   success_rate=0.2110, final_score=-55013.0 (train time 5.7s)
# Run 80/120: {'EPISODES': 5000, 'ALPHA': 0.05, 'EPS_DECAY': 0.995, 'EPSILON': 0.2, 'seed': 999} (elapsed 992.3s)
#   success_rate=0.1960, final_score=-55383.0 (train time 5.8s)
#   success_rate=0.1960, final_score=-55383.0 (train time 5.8s)
#   checkpoint saved to results/grid_search_partial_1762167236.json
# Run 81/120: {'EPISODES': 20000, 'ALPHA': 0.05, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 42} (elapsed 998.7s)
#   checkpoint saved to results/grid_search_partial_1762167236.json
# Run 81/120: {'EPISODES': 20000, 'ALPHA': 0.05, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 42} (elapsed 998.7s)
#   success_rate=0.2265, final_score=-54562.0 (train time 19.9s)
# Run 82/120: {'EPISODES': 20000, 'ALPHA': 0.03, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 123} (elapsed 1018.6s)
#   success_rate=0.2265, final_score=-54562.0 (train time 19.9s)
# Run 82/120: {'EPISODES': 20000, 'ALPHA': 0.03, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 123} (elapsed 1018.6s)
#   success_rate=0.2100, final_score=-55245.0 (train time 19.8s)
# Run 83/120: {'EPISODES': 5000, 'ALPHA': 0.1, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 42} (elapsed 1038.4s)
#   success_rate=0.2100, final_score=-55245.0 (train time 19.8s)
# Run 83/120: {'EPISODES': 5000, 'ALPHA': 0.1, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 42} (elapsed 1038.4s)
#   success_rate=0.2020, final_score=-55141.0 (train time 5.7s)
# Run 84/120: {'EPISODES': 5000, 'ALPHA': 0.05, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 123} (elapsed 1044.1s)
#   success_rate=0.2020, final_score=-55141.0 (train time 5.7s)
# Run 84/120: {'EPISODES': 5000, 'ALPHA': 0.05, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 123} (elapsed 1044.1s)
#   success_rate=0.2230, final_score=-54504.0 (train time 6.0s)
# Run 85/120: {'EPISODES': 5000, 'ALPHA': 0.1, 'EPS_DECAY': 0.999, 'EPSILON': 0.2, 'seed': 123} (elapsed 1050.1s)
#   success_rate=0.2230, final_score=-54504.0 (train time 6.0s)
# Run 85/120: {'EPISODES': 5000, 'ALPHA': 0.1, 'EPS_DECAY': 0.999, 'EPSILON': 0.2, 'seed': 123} (elapsed 1050.1s)
#   success_rate=0.2095, final_score=-54666.0 (train time 5.7s)
#   success_rate=0.2095, final_score=-54666.0 (train time 5.7s)
#   checkpoint saved to results/grid_search_partial_1762167294.json
# Run 86/120: {'EPISODES': 20000, 'ALPHA': 0.1, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 42} (elapsed 1056.5s)
#   checkpoint saved to results/grid_search_partial_1762167294.json
# Run 86/120: {'EPISODES': 20000, 'ALPHA': 0.1, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 42} (elapsed 1056.5s)
#   success_rate=0.2240, final_score=-54697.0 (train time 21.7s)
# Run 87/120: {'EPISODES': 5000, 'ALPHA': 0.1, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 42} (elapsed 1078.2s)
#   success_rate=0.2240, final_score=-54697.0 (train time 21.7s)
# Run 87/120: {'EPISODES': 5000, 'ALPHA': 0.1, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 42} (elapsed 1078.2s)
#   success_rate=0.2150, final_score=-54945.0 (train time 5.9s)
# Run 88/120: {'EPISODES': 20000, 'ALPHA': 0.1, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 999} (elapsed 1084.1s)
#   success_rate=0.2150, final_score=-54945.0 (train time 5.9s)
# Run 88/120: {'EPISODES': 20000, 'ALPHA': 0.1, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 999} (elapsed 1084.1s)
#   success_rate=0.2010, final_score=-55043.0 (train time 22.1s)
# Run 89/120: {'EPISODES': 20000, 'ALPHA': 0.05, 'EPS_DECAY': 0.999, 'EPSILON': 0.2, 'seed': 42} (elapsed 1106.2s)
#   success_rate=0.2010, final_score=-55043.0 (train time 22.1s)
# Run 89/120: {'EPISODES': 20000, 'ALPHA': 0.05, 'EPS_DECAY': 0.999, 'EPSILON': 0.2, 'seed': 42} (elapsed 1106.2s)
#   success_rate=0.1975, final_score=-55325.0 (train time 22.6s)
# Run 90/120: {'EPISODES': 20000, 'ALPHA': 0.05, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 42} (elapsed 1128.7s)
#   success_rate=0.1975, final_score=-55325.0 (train time 22.6s)
# Run 90/120: {'EPISODES': 20000, 'ALPHA': 0.05, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 42} (elapsed 1128.7s)
#   success_rate=0.2105, final_score=-54809.0 (train time 21.2s)
#   success_rate=0.2105, final_score=-54809.0 (train time 21.2s)
#   checkpoint saved to results/grid_search_partial_1762167388.json
# Run 91/120: {'EPISODES': 15000, 'ALPHA': 0.05, 'EPS_DECAY': 0.995, 'EPSILON': 0.1, 'seed': 42} (elapsed 1150.7s)
#   checkpoint saved to results/grid_search_partial_1762167388.json
# Run 91/120: {'EPISODES': 15000, 'ALPHA': 0.05, 'EPS_DECAY': 0.995, 'EPSILON': 0.1, 'seed': 42} (elapsed 1150.7s)
#   success_rate=0.2120, final_score=-54991.0 (train time 17.5s)
# Run 92/120: {'EPISODES': 10000, 'ALPHA': 0.03, 'EPS_DECAY': 0.999, 'EPSILON': 0.2, 'seed': 123} (elapsed 1168.2s)
#   success_rate=0.2120, final_score=-54991.0 (train time 17.5s)
# Run 92/120: {'EPISODES': 10000, 'ALPHA': 0.03, 'EPS_DECAY': 0.999, 'EPSILON': 0.2, 'seed': 123} (elapsed 1168.2s)
#   success_rate=0.2135, final_score=-54953.0 (train time 11.8s)
# Run 93/120: {'EPISODES': 10000, 'ALPHA': 0.01, 'EPS_DECAY': 0.999, 'EPSILON': 0.1, 'seed': 123} (elapsed 1180.1s)
#   success_rate=0.2135, final_score=-54953.0 (train time 11.8s)
# Run 93/120: {'EPISODES': 10000, 'ALPHA': 0.01, 'EPS_DECAY': 0.999, 'EPSILON': 0.1, 'seed': 123} (elapsed 1180.1s)
#   success_rate=0.2080, final_score=-55094.0 (train time 11.9s)
# Run 94/120: {'EPISODES': 15000, 'ALPHA': 0.1, 'EPS_DECAY': 0.999, 'EPSILON': 0.2, 'seed': 42} (elapsed 1191.9s)
#   success_rate=0.2080, final_score=-55094.0 (train time 11.9s)
# Run 94/120: {'EPISODES': 15000, 'ALPHA': 0.1, 'EPS_DECAY': 0.999, 'EPSILON': 0.2, 'seed': 42} (elapsed 1191.9s)
#   success_rate=0.2165, final_score=-54847.0 (train time 16.7s)
# Run 95/120: {'EPISODES': 20000, 'ALPHA': 0.1, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 999} (elapsed 1208.7s)
#   success_rate=0.2165, final_score=-54847.0 (train time 16.7s)
# Run 95/120: {'EPISODES': 20000, 'ALPHA': 0.1, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 999} (elapsed 1208.7s)
#   success_rate=0.2165, final_score=-54732.0 (train time 22.2s)
#   success_rate=0.2165, final_score=-54732.0 (train time 22.2s)
#   checkpoint saved to results/grid_search_partial_1762167469.json
# Run 96/120: {'EPISODES': 5000, 'ALPHA': 0.01, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 999} (elapsed 1231.6s)
#   checkpoint saved to results/grid_search_partial_1762167469.json
# Run 96/120: {'EPISODES': 5000, 'ALPHA': 0.01, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 999} (elapsed 1231.6s)
#   success_rate=0.2105, final_score=-55244.0 (train time 6.5s)
# Run 97/120: {'EPISODES': 15000, 'ALPHA': 0.1, 'EPS_DECAY': 0.995, 'EPSILON': 0.3, 'seed': 999} (elapsed 1238.1s)
#   success_rate=0.2105, final_score=-55244.0 (train time 6.5s)
# Run 97/120: {'EPISODES': 15000, 'ALPHA': 0.1, 'EPS_DECAY': 0.995, 'EPSILON': 0.3, 'seed': 999} (elapsed 1238.1s)
#   success_rate=0.2055, final_score=-55209.0 (train time 16.9s)
# Run 98/120: {'EPISODES': 5000, 'ALPHA': 0.01, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 999} (elapsed 1255.0s)
#   success_rate=0.2055, final_score=-55209.0 (train time 16.9s)
# Run 98/120: {'EPISODES': 5000, 'ALPHA': 0.01, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 999} (elapsed 1255.0s)
#   success_rate=0.2075, final_score=-55020.0 (train time 6.2s)
# Run 99/120: {'EPISODES': 10000, 'ALPHA': 0.01, 'EPS_DECAY': 0.99, 'EPSILON': 0.3, 'seed': 999} (elapsed 1261.2s)
#   success_rate=0.2075, final_score=-55020.0 (train time 6.2s)
# Run 99/120: {'EPISODES': 10000, 'ALPHA': 0.01, 'EPS_DECAY': 0.99, 'EPSILON': 0.3, 'seed': 999} (elapsed 1261.2s)
#   success_rate=0.2260, final_score=-54718.0 (train time 11.6s)
# Run 100/120: {'EPISODES': 10000, 'ALPHA': 0.01, 'EPS_DECAY': 0.99, 'EPSILON': 0.3, 'seed': 123} (elapsed 1272.9s)
#   success_rate=0.2260, final_score=-54718.0 (train time 11.6s)
# Run 100/120: {'EPISODES': 10000, 'ALPHA': 0.01, 'EPS_DECAY': 0.99, 'EPSILON': 0.3, 'seed': 123} (elapsed 1272.9s)
#   success_rate=0.2045, final_score=-55111.0 (train time 12.1s)
#   success_rate=0.2045, final_score=-55111.0 (train time 12.1s)
#   checkpoint saved to results/grid_search_partial_1762167523.json
# Run 101/120: {'EPISODES': 15000, 'ALPHA': 0.1, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 999} (elapsed 1285.9s)
#   checkpoint saved to results/grid_search_partial_1762167523.json
# Run 101/120: {'EPISODES': 15000, 'ALPHA': 0.1, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 999} (elapsed 1285.9s)
#   success_rate=0.2170, final_score=-54771.0 (train time 16.9s)
# Run 102/120: {'EPISODES': 20000, 'ALPHA': 0.1, 'EPS_DECAY': 0.995, 'EPSILON': 0.2, 'seed': 123} (elapsed 1302.8s)
#   success_rate=0.2170, final_score=-54771.0 (train time 16.9s)
# Run 102/120: {'EPISODES': 20000, 'ALPHA': 0.1, 'EPS_DECAY': 0.995, 'EPSILON': 0.2, 'seed': 123} (elapsed 1302.8s)
#   success_rate=0.2010, final_score=-55293.0 (train time 23.0s)
# Run 103/120: {'EPISODES': 20000, 'ALPHA': 0.05, 'EPS_DECAY': 0.995, 'EPSILON': 0.3, 'seed': 123} (elapsed 1325.8s)
#   success_rate=0.2010, final_score=-55293.0 (train time 23.0s)
# Run 103/120: {'EPISODES': 20000, 'ALPHA': 0.05, 'EPS_DECAY': 0.995, 'EPSILON': 0.3, 'seed': 123} (elapsed 1325.8s)
#   success_rate=0.2200, final_score=-54555.0 (train time 28.0s)
# Run 104/120: {'EPISODES': 5000, 'ALPHA': 0.1, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 123} (elapsed 1353.8s)
#   success_rate=0.2200, final_score=-54555.0 (train time 28.0s)
# Run 104/120: {'EPISODES': 5000, 'ALPHA': 0.1, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 123} (elapsed 1353.8s)
#   success_rate=0.2085, final_score=-54873.0 (train time 9.2s)
# Run 105/120: {'EPISODES': 15000, 'ALPHA': 0.1, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 999} (elapsed 1363.0s)
#   success_rate=0.2085, final_score=-54873.0 (train time 9.2s)
# Run 105/120: {'EPISODES': 15000, 'ALPHA': 0.1, 'EPS_DECAY': 0.99, 'EPSILON': 0.2, 'seed': 999} (elapsed 1363.0s)
#   success_rate=0.1975, final_score=-55085.0 (train time 19.0s)
#   success_rate=0.1975, final_score=-55085.0 (train time 19.0s)
#   checkpoint saved to results/grid_search_partial_1762167620.json
# Run 106/120: {'EPISODES': 15000, 'ALPHA': 0.05, 'EPS_DECAY': 0.999, 'EPSILON': 0.2, 'seed': 123} (elapsed 1382.8s)
#   checkpoint saved to results/grid_search_partial_1762167620.json
# Run 106/120: {'EPISODES': 15000, 'ALPHA': 0.05, 'EPS_DECAY': 0.999, 'EPSILON': 0.2, 'seed': 123} (elapsed 1382.8s)
#   success_rate=0.2100, final_score=-54845.0 (train time 16.7s)
# Run 107/120: {'EPISODES': 10000, 'ALPHA': 0.05, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 42} (elapsed 1399.5s)
#   success_rate=0.2100, final_score=-54845.0 (train time 16.7s)
# Run 107/120: {'EPISODES': 10000, 'ALPHA': 0.05, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 42} (elapsed 1399.5s)
#   success_rate=0.1815, final_score=-55802.0 (train time 12.1s)
# Run 108/120: {'EPISODES': 20000, 'ALPHA': 0.03, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 123} (elapsed 1411.6s)
#   success_rate=0.1815, final_score=-55802.0 (train time 12.1s)
# Run 108/120: {'EPISODES': 20000, 'ALPHA': 0.03, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 123} (elapsed 1411.6s)
#   success_rate=0.2195, final_score=-54896.0 (train time 19.9s)
# Run 109/120: {'EPISODES': 5000, 'ALPHA': 0.01, 'EPS_DECAY': 0.995, 'EPSILON': 0.3, 'seed': 999} (elapsed 1431.6s)
#   success_rate=0.2195, final_score=-54896.0 (train time 19.9s)
# Run 109/120: {'EPISODES': 5000, 'ALPHA': 0.01, 'EPS_DECAY': 0.995, 'EPSILON': 0.3, 'seed': 999} (elapsed 1431.6s)
#   success_rate=0.1880, final_score=-55644.0 (train time 5.6s)
# Run 110/120: {'EPISODES': 20000, 'ALPHA': 0.05, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 999} (elapsed 1437.2s)
#   success_rate=0.1880, final_score=-55644.0 (train time 5.6s)
# Run 110/120: {'EPISODES': 20000, 'ALPHA': 0.05, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 999} (elapsed 1437.2s)
#   success_rate=0.2190, final_score=-54637.0 (train time 19.5s)
#   success_rate=0.2190, final_score=-54637.0 (train time 19.5s)
#   checkpoint saved to results/grid_search_partial_1762167695.json
# Run 111/120: {'EPISODES': 15000, 'ALPHA': 0.1, 'EPS_DECAY': 0.999, 'EPSILON': 0.1, 'seed': 42} (elapsed 1457.5s)
#   checkpoint saved to results/grid_search_partial_1762167695.json
# Run 111/120: {'EPISODES': 15000, 'ALPHA': 0.1, 'EPS_DECAY': 0.999, 'EPSILON': 0.1, 'seed': 42} (elapsed 1457.5s)
#   success_rate=0.2265, final_score=-54737.0 (train time 15.1s)
# Run 112/120: {'EPISODES': 15000, 'ALPHA': 0.01, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 999} (elapsed 1472.6s)
#   success_rate=0.2265, final_score=-54737.0 (train time 15.1s)
# Run 112/120: {'EPISODES': 15000, 'ALPHA': 0.01, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 999} (elapsed 1472.6s)
#   success_rate=0.2215, final_score=-54707.0 (train time 14.9s)
# Run 113/120: {'EPISODES': 5000, 'ALPHA': 0.1, 'EPS_DECAY': 0.999, 'EPSILON': 0.1, 'seed': 999} (elapsed 1487.5s)
#   success_rate=0.2215, final_score=-54707.0 (train time 14.9s)
# Run 113/120: {'EPISODES': 5000, 'ALPHA': 0.1, 'EPS_DECAY': 0.999, 'EPSILON': 0.1, 'seed': 999} (elapsed 1487.5s)
#   success_rate=0.2075, final_score=-55130.0 (train time 5.6s)
# Run 114/120: {'EPISODES': 10000, 'ALPHA': 0.1, 'EPS_DECAY': 0.995, 'EPSILON': 0.1, 'seed': 123} (elapsed 1493.1s)
#   success_rate=0.2075, final_score=-55130.0 (train time 5.6s)
# Run 114/120: {'EPISODES': 10000, 'ALPHA': 0.1, 'EPS_DECAY': 0.995, 'EPSILON': 0.1, 'seed': 123} (elapsed 1493.1s)
#   success_rate=0.2050, final_score=-55120.0 (train time 10.3s)
# Run 115/120: {'EPISODES': 15000, 'ALPHA': 0.05, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 123} (elapsed 1503.4s)
#   success_rate=0.2050, final_score=-55120.0 (train time 10.3s)
# Run 115/120: {'EPISODES': 15000, 'ALPHA': 0.05, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 123} (elapsed 1503.4s)
#   New best -> success_rate=0.2330, saved weights to results/best_weights_1762167757.npz
#   New best -> success_rate=0.2330, saved weights to results/best_weights_1762167757.npz
#   checkpoint saved to results/grid_search_partial_1762167757.json
# Run 116/120: {'EPISODES': 15000, 'ALPHA': 0.03, 'EPS_DECAY': 0.999, 'EPSILON': 0.2, 'seed': 42} (elapsed 1519.2s)
#   checkpoint saved to results/grid_search_partial_1762167757.json
# Run 116/120: {'EPISODES': 15000, 'ALPHA': 0.03, 'EPS_DECAY': 0.999, 'EPSILON': 0.2, 'seed': 42} (elapsed 1519.2s)
#   success_rate=0.2115, final_score=-54862.0 (train time 15.0s)
# Run 117/120: {'EPISODES': 5000, 'ALPHA': 0.01, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 999} (elapsed 1534.1s)
#   success_rate=0.2115, final_score=-54862.0 (train time 15.0s)
# Run 117/120: {'EPISODES': 5000, 'ALPHA': 0.01, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 999} (elapsed 1534.1s)
#   success_rate=0.2115, final_score=-55142.0 (train time 5.6s)
# Run 118/120: {'EPISODES': 5000, 'ALPHA': 0.01, 'EPS_DECAY': 0.995, 'EPSILON': 0.1, 'seed': 123} (elapsed 1539.8s)
#   success_rate=0.2115, final_score=-55142.0 (train time 5.6s)
# Run 118/120: {'EPISODES': 5000, 'ALPHA': 0.01, 'EPS_DECAY': 0.995, 'EPSILON': 0.1, 'seed': 123} (elapsed 1539.8s)
#   success_rate=0.2115, final_score=-55122.0 (train time 5.6s)
# Run 119/120: {'EPISODES': 10000, 'ALPHA': 0.03, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 999} (elapsed 1545.4s)
#   success_rate=0.2115, final_score=-55122.0 (train time 5.6s)
# Run 119/120: {'EPISODES': 10000, 'ALPHA': 0.03, 'EPS_DECAY': 0.99, 'EPSILON': 0.1, 'seed': 999} (elapsed 1545.4s)
#   success_rate=0.2280, final_score=-54659.0 (train time 10.2s)
# Run 120/120: {'EPISODES': 10000, 'ALPHA': 0.01, 'EPS_DECAY': 0.999, 'EPSILON': 0.2, 'seed': 42} (elapsed 1555.6s)
#   success_rate=0.2280, final_score=-54659.0 (train time 10.2s)
# Run 120/120: {'EPISODES': 10000, 'ALPHA': 0.01, 'EPS_DECAY': 0.999, 'EPSILON': 0.2, 'seed': 42} (elapsed 1555.6s)
#   success_rate=0.2105, final_score=-54979.0 (train time 10.3s)
#   success_rate=0.2105, final_score=-54979.0 (train time 10.3s)
#   checkpoint saved to results/grid_search_partial_1762167804.json
#   checkpoint saved to results/grid_search_partial_1762167804.json
# Grid search complete. Results saved to results/grid_search_full_1762167805.json
#
# BEST RUN:
# params = {'EPISODES': 15000, 'ALPHA': 0.05, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 123}
# success_rate = 0.233
# final_score = -54284.0
# Grid search complete. Results saved to results/grid_search_full_1762167805.json
#
# BEST RUN:
# params = {'EPISODES': 15000, 'ALPHA': 0.05, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 123}
# success_rate = 0.233
# final_score = -54284.0

# %%
# --- Single final train using user-provided best params
params = {'EPISODES': 15000, 'ALPHA': 0.05, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 123}
print('Training with params:', params)
out = train_agent(params, verbose=True)
metrics = evaluate_agent(out['w'])
ts = int(time.time())
out_dir = Path('results')
out_dir.mkdir(parents=True, exist_ok=True)
weights_path = out_dir / f"final_run_weights_{ts}.npz"
np.savez_compressed(weights_path, w=out['w'], params=json.dumps(params))
metrics_path = out_dir / f"final_run_metrics_{ts}.json"
with open(metrics_path, 'w', encoding='utf-8') as fp:
    json.dump({'params': params, 'metrics': metrics}, fp, indent=2, default=str)
print('Saved weights to', weights_path)
print('Saved metrics to', metrics_path)
print('\nFINAL METRICS:')
print('success_rate =', metrics['success_rate'])
print('final_score =', metrics['final_score'])
# Out:
# Training with params: {'EPISODES': 15000, 'ALPHA': 0.05, 'EPS_DECAY': 0.999, 'EPSILON': 0.3, 'seed': 123}
# ep 3000/15000: wins=0.210
# ep 6000/15000: wins=0.260
# ep 9000/15000: wins=0.180
# ep 12000/15000: wins=0.160
# ep 15000/15000: wins=0.220
# Saved weights to results/final_run_weights_1762167962.npz
# Saved metrics to results/final_run_metrics_1762167962.json
#
# FINAL METRICS:
# success_rate = 0.233
# final_score = -54284.0

# %%
# Training curves and metrics
import numpy as np

WINDOW = 50

def moving_avg(x, w=WINDOW):
    if len(x) < 1:
        return np.array([])
    x = np.array(x, dtype=float)
    if len(x) < w:
        w = len(x)
    return np.convolve(x, np.ones(w)/w, mode='valid')

fig, axes = plt.subplots(3, 1, figsize=(10, 10))
axes[0].plot(train_rewards, color='#4C72B0', alpha=0.4, label='reward')
axes[0].plot(range(WINDOW-1, WINDOW-1+len(moving_avg(train_rewards))), moving_avg(train_rewards), color='#4C72B0', label=f'ma{WINDOW}')
axes[0].set_title('Episode Reward')
axes[0].legend()

axes[1].plot(train_wins, color='#55A868', alpha=0.4, label='win (0/1)')
axes[1].plot(range(WINDOW-1, WINDOW-1+len(moving_avg(train_wins))), moving_avg(train_wins), color='#55A868', label=f'ma{WINDOW}')
axes[1].set_title('Win Rate (moving average)')
axes[1].legend()

axes[2].plot(train_wrong, color='#C44E52', alpha=0.3, label='wrong guesses')
axes[2].plot(train_repeated, color='#8172B2', alpha=0.3, label='repeated guesses')
axes[2].plot(range(WINDOW-1, WINDOW-1+len(moving_avg(train_wrong))), moving_avg(train_wrong), color='#C44E52', label='wrong ma')
axes[2].plot(range(WINDOW-1, WINDOW-1+len(moving_avg(train_repeated))), moving_avg(train_repeated), color='#8172B2', label='repeat ma')
axes[2].set_title('Mistakes per Episode')
axes[2].legend()

plt.tight_layout()
plt.show()

# %%
# Plot: Episode vs Win Rate for multiple window sizes
from pathlib import Path
windows = [1, 10, 50, 100, 200]
plt.figure(figsize=(12,6))
plotted = False
for w in windows:
    if len(train_wins) < w:
        print(f"Skipping window {w} (training length {len(train_wins)} < {w})")
        continue
    ma = moving_avg(train_wins, w)
    x = np.arange(w-1, w-1 + len(ma))
    plt.plot(x, ma, label=f"MA w={w}")
    plotted = True
if not plotted:
    print("No windowed series available to plot. Run training first.")
else:
    plt.xlabel('Episode')
    plt.ylabel('Win rate (moving average)')
    plt.title('Episode vs Win rate — compare window sizes')
    plt.legend(title='Window')
    plt.grid(alpha=0.3)
    plt.tight_layout()
    out_dir = Path('results')
    out_dir.mkdir(parents=True, exist_ok=True)
    out_path = out_dir / 'episode_vs_accuracy_windows.png'
    plt.savefig(out_path)
    plt.show()
    print('Saved plot to', out_path)
# Out:
# Saved plot to results/episode_vs_accuracy_windows.png

# %%
# Save learned weights (optional)
np.savez_compressed('agent_weights.npz', w=w)
print('Saved agent weights to agent_weights.npz')
# Out:
# Saved agent weights to agent_weights.npz

# %%
# Evaluation on test set

def play_game(word: str):
    guessed = set()
    mask = '_' * len(word)
    lives = MAX_LIVES
    wrongs = 0
    repeats = 0
    total_guesses = 0

    done = False
    while not done:
        probs_vec = hmm_probs_vector(mask, guessed)
        # greedy action
        acts = available_actions(guessed)
        if not acts:
            break
        qvals = [q_value(mask, guessed, lives, probs_vec, a) for a in acts]
        idx = int(np.argmax(qvals))
        a = acts[idx]

        new_mask, guessed, lives, r, done, repeated, wrong = step_env(word, mask, guessed, a, lives)
        total_guesses += 1
        wrongs += int(wrong)
        repeats += int(repeated)
        mask = new_mask

    win = int(mask == word)
    return {
        'win': win,
        'wrong': wrongs,
        'repeated': repeats,
        'guesses': total_guesses,
        'length': len(word)
    }

results = [play_game(w) for w in test_words]

success_rate = np.mean([r['win'] for r in results]) if results else 0.0
total_wrong = int(np.sum([r['wrong'] for r in results]))
total_repeated = int(np.sum([r['repeated'] for r in results]))

final_score = (success_rate * 2000) - (total_wrong * 5) - (total_repeated * 2)

print({
    'games': len(results),
    'success_rate': round(success_rate, 4),
    'total_wrong': total_wrong,
    'total_repeated': total_repeated,
    'final_score': round(final_score, 2)
})
